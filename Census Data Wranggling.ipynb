# %% [markdown]
# # **Data Exploration**

# %% [markdown]
# we're analyzing 4 datasets from US Census
# 1. Housing fuel heating
# 2. Income in the past 12 months
# 3. Poverty Status in the past 12 months
# 4. Median Gross Rent

# %% [markdown]
# # First Dataset:
# -Housing fuel heating data from Census for each state

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from functools import reduce

df_heating_fuel = pd.read_csv("/content/drive/MyDrive/DS4A/DS4A Team 14 - Fall 2022/DATA CURATION/Data Source Copies/US Census/1_HOUSE HEATING FUEL.csv", delimiter=',')
df_heating_fuel.head()
# Out:
#                Label (Grouping) Alabama!!Estimate Alaska!!Estimate  \
# 0                        Total:         1,967,559          271,311
# 1                   Utility gas           529,760          136,638
# 2      Bottled, tank, or LP gas           109,278            7,501
# 3                   Electricity         1,299,491           37,403
# 4      Fuel oil, kerosene, etc.             2,289           72,709
#
#   Arizona!!Estimate Arkansas!!Estimate California!!Estimate  \
# 0         2,817,723          1,183,675           13,429,063
# 1           935,440            435,082            8,169,527
# 2            79,939             74,310              464,435
# 3         1,687,012            631,405            3,990,075
# 4             2,061              1,473               30,731
#
#   Colorado!!Estimate Connecticut!!Estimate Delaware!!Estimate  \
# 0          2,313,042             1,428,313            395,656
# 1          1,527,676               506,772            168,200
# 2            113,314                80,721             36,954
# 3            603,564               258,306            148,031
# 4              2,167               532,053             34,587
#
#   District of Columbia!!Estimate  ... Texas!!Estimate Utah!!Estimate  \
# 0                        319,565  ...      10,796,247      1,101,499
# 1                        160,024  ...       3,652,862        852,377
# 2                          3,540  ...         321,711         27,747
# 3                        142,056  ...       6,679,670        198,288
# 4                          4,391  ...          10,027          2,138
#
#   Vermont!!Estimate Virginia!!Estimate Washington!!Estimate  \
# 0           270,163          3,331,461            3,022,255
# 1            50,677          1,075,840            1,012,119
# 2            51,992            145,015               95,724
# 3            22,510          1,905,058            1,741,348
# 4           105,005            116,452               44,429
#
#   West Virginia!!Estimate Wisconsin!!Estimate Wyoming!!Estimate  \
# 0                 722,201           2,449,970           242,763
# 1                 298,606           1,582,718           144,576
# 2                  36,595             296,947            26,413
# 3                 326,799             429,522            57,846
# 4                  14,852              36,529               161
#
#   Puerto Rico!!Estimate United States!!Estimate
# 0             1,165,982             127,544,730
# 1                 1,015              59,246,257
# 2                 7,847               6,326,791
# 3               106,536              52,279,174
# 4                   194               5,218,757
#
# [5 rows x 54 columns]

# %%
df_heating_fuel.shape
# Out:
# (10, 54)

# %%
df_heating_fuel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Label (Grouping)                10 non-null     object
#  1   Alabama!!Estimate               10 non-null     object
#  2   Alaska!!Estimate                10 non-null     object
#  3   Arizona!!Estimate               10 non-null     object
#  4   Arkansas!!Estimate              10 non-null     object
#  5   California!!Estimate            10 non-null     object
#  6   Colorado!!Estimate              10 non-null     object
#  7   Connecticut!!Estimate           10 non-null     object
#  8   Delaware!!Estimate              10 non-null     object
#  9   District of Columbia!!Estimate  10 non-null     object
#  10  Florida!!Estimate               10 non-null     object
#  11  Georgia!!Estimate               10 non-null     object
#  12  Hawaii!!Estimate                10 non-null     object
#  13  Idaho!!Estimate                 10 non-null     object
#  14  Illinois!!Estimate              10 non-null     object
#  15  Indiana!!Estimate               10 non-null     object
#  16  Iowa!!Estimate                  10 non-null     object
#  17  Kansas!!Estimate                10 non-null     object
#  18  Kentucky!!Estimate              10 non-null     object
#  19  Louisiana!!Estimate             10 non-null     object
#  20  Maine!!Estimate                 10 non-null     object
#  21  Maryland!!Estimate              10 non-null     object
#  22  Massachusetts!!Estimate         10 non-null     object
#  23  Michigan!!Estimate              10 non-null     object
#  24  Minnesota!!Estimate             10 non-null     object
#  25  Mississippi!!Estimate           10 non-null     object
#  26  Missouri!!Estimate              10 non-null     object
#  27  Montana!!Estimate               10 non-null     object
#  28  Nebraska!!Estimate              10 non-null     object
#  29  Nevada!!Estimate                10 non-null     object
#  30  New Hampshire!!Estimate         10 non-null     object
#  31  New Jersey!!Estimate            10 non-null     object
#  32  New Mexico!!Estimate            10 non-null     object
#  33  New York!!Estimate              10 non-null     object
#  34  North Carolina!!Estimate        10 non-null     object
#  35  North Dakota!!Estimate          10 non-null     object
#  36  Ohio!!Estimate                  10 non-null     object
#  37  Oklahoma!!Estimate              10 non-null     object
#  38  Oregon!!Estimate                10 non-null     object
#  39  Pennsylvania!!Estimate          10 non-null     object
#  40  Rhode Island!!Estimate          10 non-null     object
#  41  South Carolina!!Estimate        10 non-null     object
#  42  South Dakota!!Estimate          10 non-null     object
#  43  Tennessee!!Estimate             10 non-null     object
#  44  Texas!!Estimate                 10 non-null     object
#  45  Utah!!Estimate                  10 non-null     object
#  46  Vermont!!Estimate               10 non-null     object
#  47  Virginia!!Estimate              10 non-null     object
#  48  Washington!!Estimate            10 non-null     object
#  49  West Virginia!!Estimate         10 non-null     object
#  50  Wisconsin!!Estimate             10 non-null     object
#  51  Wyoming!!Estimate               10 non-null     object
#  52  Puerto Rico!!Estimate           10 non-null     object
#  53  United States!!Estimate         10 non-null     object
# dtypes: object(54)
# memory usage: 4.3+ KB

# %%
df_heating_fuel.describe()
# Out:
#        Label (Grouping) Alabama!!Estimate Alaska!!Estimate Arizona!!Estimate  \
# count                10                10               10                10
# unique               10                10               10                10
# top              Total:         1,967,559          271,311         2,817,723
# freq                  1                 1                1                 1
#
#        Arkansas!!Estimate California!!Estimate Colorado!!Estimate  \
# count                  10                   10                 10
# unique                 10                   10                 10
# top             1,183,675           13,429,063          2,313,042
# freq                    1                    1                  1
#
#        Connecticut!!Estimate Delaware!!Estimate  \
# count                     10                 10
# unique                    10                 10
# top                1,428,313            395,656
# freq                       1                  1
#
#        District of Columbia!!Estimate  ... Texas!!Estimate Utah!!Estimate  \
# count                              10  ...              10             10
# unique                              9  ...              10             10
# top                                 0  ...      10,796,247      1,101,499
# freq                                2  ...               1              1
#
#        Vermont!!Estimate Virginia!!Estimate Washington!!Estimate  \
# count                 10                 10                   10
# unique                10                 10                   10
# top              270,163          3,331,461            3,022,255
# freq                   1                  1                    1
#
#        West Virginia!!Estimate Wisconsin!!Estimate Wyoming!!Estimate  \
# count                       10                  10                10
# unique                      10                  10                10
# top                    722,201           2,449,970           242,763
# freq                         1                   1                 1
#
#        Puerto Rico!!Estimate United States!!Estimate
# count                     10                      10
# unique                    10                      10
# top                1,165,982             127,544,730
# freq                       1                       1
#
# [4 rows x 54 columns]

# %% [markdown]
# # Second Dataset:  Income in the Past 12 months

# %%
df_income = pd.read_csv("/content/drive/MyDrive/DS4A/DS4A Team 14 - Fall 2022/DATA CURATION/Data Source Copies/US Census/2_INCOME IN THE PAST 12 MONTHS (IN 2021 INFLATION-ADJUSTED DOLLARS).csv", delimiter=',')
df_income.head()
# Out:
#          Label (Grouping) Alabama!!Households!!Estimate  \
# 0                   Total                     1,967,559
# 1       Less than $10,000                          7.7%
# 2      $10,000 to $14,999                          5.6%
# 3      $15,000 to $24,999                         10.4%
# 4      $25,000 to $34,999                          9.4%
#
#   Alabama!!Families!!Estimate Alabama!!Married-couple families!!Estimate  \
# 0                   1,271,383                                    904,392
# 1                        4.6%                                       1.7%
# 2                        2.9%                                       1.3%
# 3                        6.9%                                       3.8%
# 4                        7.9%                                       5.8%
#
#   Alabama!!Nonfamily households!!Estimate Alaska!!Households!!Estimate  \
# 0                                 696,176                      271,311
# 1                                   14.5%                         5.4%
# 2                                   10.8%                         3.0%
# 3                                   17.5%                         6.3%
# 4                                   12.1%                         6.2%
#
#   Alaska!!Families!!Estimate Alaska!!Married-couple families!!Estimate  \
# 0                    172,376                                   129,937
# 1                       2.6%                                      0.8%
# 2                       1.3%                                      0.7%
# 3                       4.1%                                      2.4%
# 4                       4.4%                                      2.7%
#
#   Alaska!!Nonfamily households!!Estimate Arizona!!Households!!Estimate  ...  \
# 0                                 98,935                     2,817,723  ...
# 1                                  10.9%                          5.6%  ...
# 2                                   6.1%                          3.2%  ...
# 3                                  10.3%                          7.1%  ...
# 4                                  10.7%                          7.8%  ...
#
#   Wyoming!!Married-couple families!!Estimate  \
# 0                                    120,894
# 1                                       1.6%
# 2                                       0.8%
# 3                                       2.7%
# 4                                       4.8%
#
#   Wyoming!!Nonfamily households!!Estimate Puerto Rico!!Households!!Estimate  \
# 0                                  91,930                         1,165,982
# 1                                   11.3%                             24.6%
# 2                                    7.2%                             11.3%
# 3                                   14.9%                             18.4%
# 4                                   13.4%                             12.8%
#
#   Puerto Rico!!Families!!Estimate  \
# 0                         738,853
# 1                           18.6%
# 2                            8.7%
# 3                           18.7%
# 4                           13.9%
#
#   Puerto Rico!!Married-couple families!!Estimate  \
# 0                                        401,781
# 1                                           8.7%
# 2                                           7.3%
# 3                                          17.4%
# 4                                          14.7%
#
#   Puerto Rico!!Nonfamily households!!Estimate  \
# 0                                     427,129
# 1                                       37.8%
# 2                                       16.8%
# 3                                       18.9%
# 4                                       10.2%
#
#   United States!!Households!!Estimate United States!!Families!!Estimate  \
# 0                         127,544,730                        82,464,986
# 1                                6.0%                              3.7%
# 2                                3.9%                              2.0%
# 3                                7.5%                              5.0%
# 4                                7.8%                              6.2%
#
#   United States!!Married-couple families!!Estimate  \
# 0                                       60,360,084
# 1                                             1.6%
# 2                                             1.0%
# 3                                             3.0%
# 4                                             4.3%
#
#   United States!!Nonfamily households!!Estimate
# 0                                    45,079,744
# 1                                         11.3%
# 2                                          7.6%
# 3                                         12.8%
# 4                                         11.4%
#
# [5 rows x 213 columns]

# %%
df_income.shape
# Out:
# (17, 213)

# %%
df_income.info
# Out:
# <bound method DataFrame.info of                               Label (Grouping) Alabama!!Households!!Estimate  \
# 0                                        Total                     1,967,559
# 1                            Less than $10,000                          7.7%
# 2                           $10,000 to $14,999                          5.6%
# 3                           $15,000 to $24,999                         10.4%
# 4                           $25,000 to $34,999                          9.4%
# 5                           $35,000 to $49,999                         13.3%
# 6                           $50,000 to $74,999                         17.3%
# 7                           $75,000 to $99,999                         12.1%
# 8                         $100,000 to $149,999                         13.2%
# 9                         $150,000 to $199,999                          5.8%
# 10                            $200,000 or more                          5.2%
# 11                     Median income (dollars)                        53,913
# 12                       Mean income (dollars)                        75,923
# 13                           PERCENT ALLOCATED                           NaN
# 14      Household income in the past 12 months                         41.0%
# 15         Family income in the past 12 months                           (X)
# 16      Nonfamily income in the past 12 months                           (X)
#
#    Alabama!!Families!!Estimate Alabama!!Married-couple families!!Estimate  \
# 0                    1,271,383                                    904,392
# 1                         4.6%                                       1.7%
# 2                         2.9%                                       1.3%
# 3                         6.9%                                       3.8%
# 4                         7.9%                                       5.8%
# 5                        12.1%                                      10.5%
# 6                        18.3%                                      18.2%
# 7                        14.9%                                      16.9%
# 8                        17.3%                                      21.7%
# 9                         8.0%                                      10.4%
# 10                        7.2%                                       9.6%
# 11                      71,006                                     87,316
# 12                      92,591                                    109,580
# 13                         NaN                                        NaN
# 14                         (X)                                        (X)
# 15                       43.2%                                        (X)
# 16                         (X)                                        (X)
#
#    Alabama!!Nonfamily households!!Estimate Alaska!!Households!!Estimate  \
# 0                                  696,176                      271,311
# 1                                    14.5%                         5.4%
# 2                                    10.8%                         3.0%
# 3                                    17.5%                         6.3%
# 4                                    12.1%                         6.2%
# 5                                    15.5%                        10.3%
# 6                                    15.4%                        16.7%
# 7                                     6.6%                        13.6%
# 8                                     5.1%                        18.6%
# 9                                     1.4%                         9.7%
# 10                                    1.2%                        10.2%
# 11                                  30,575                       77,845
# 12                                  42,781                      100,519
# 13                                     NaN                          NaN
# 14                                     (X)                        36.7%
# 15                                     (X)                          (X)
# 16                                   36.0%                          (X)
#
#    Alaska!!Families!!Estimate Alaska!!Married-couple families!!Estimate  \
# 0                     172,376                                   129,937
# 1                        2.6%                                      0.8%
# 2                        1.3%                                      0.7%
# 3                        4.1%                                      2.4%
# 4                        4.4%                                      2.7%
# 5                        9.2%                                      7.4%
# 6                       16.1%                                     15.6%
# 7                       14.8%                                     14.8%
# 8                       21.4%                                     23.8%
# 9                       12.3%                                     14.5%
# 10                      13.7%                                     17.1%
# 11                     95,344                                   109,728
# 12                    117,828                                   133,300
# 13                        NaN                                       NaN
# 14                        (X)                                       (X)
# 15                      39.2%                                       (X)
# 16                        (X)                                       (X)
#
#    Alaska!!Nonfamily households!!Estimate Arizona!!Households!!Estimate  ...  \
# 0                                  98,935                     2,817,723  ...
# 1                                   10.9%                          5.6%  ...
# 2                                    6.1%                          3.2%  ...
# 3                                   10.3%                          7.1%  ...
# 4                                   10.7%                          7.8%  ...
# 5                                   13.7%                         12.4%  ...
# 6                                   17.3%                         17.8%  ...
# 7                                   10.7%                         13.6%  ...
# 8                                   12.9%                         17.1%  ...
# 9                                    4.7%                          7.2%  ...
# 10                                   2.7%                          8.1%  ...
# 11                                 48,081                        69,056  ...
# 12                                 64,656                        93,177  ...
# 13                                    NaN                           NaN  ...
# 14                                    (X)                         40.3%  ...
# 15                                    (X)                           (X)  ...
# 16                                  31.1%                           (X)  ...
#
#    Wyoming!!Married-couple families!!Estimate  \
# 0                                     120,894
# 1                                        1.6%
# 2                                        0.8%
# 3                                        2.7%
# 4                                        4.8%
# 5                                        7.1%
# 6                                       18.6%
# 7                                       18.8%
# 8                                       25.5%
# 9                                       11.7%
# 10                                       8.3%
# 11                                     93,500
# 12                                    114,752
# 13                                        NaN
# 14                                        (X)
# 15                                        (X)
# 16                                        (X)
#
#    Wyoming!!Nonfamily households!!Estimate Puerto Rico!!Households!!Estimate  \
# 0                                   91,930                         1,165,982
# 1                                    11.3%                             24.6%
# 2                                     7.2%                             11.3%
# 3                                    14.9%                             18.4%
# 4                                    13.4%                             12.8%
# 5                                    16.1%                             12.0%
# 6                                    18.0%                             10.7%
# 7                                     8.1%                              4.5%
# 8                                     5.7%                              3.3%
# 9                                     2.0%                              1.0%
# 10                                    3.3%                              1.4%
# 11                                  36,982                            22,237
# 12                                  54,175                            35,452
# 13                                     NaN                               NaN
# 14                                     (X)                             36.3%
# 15                                     (X)                               (X)
# 16                                   31.3%                               (X)
#
#    Puerto Rico!!Families!!Estimate  \
# 0                          738,853
# 1                            18.6%
# 2                             8.7%
# 3                            18.7%
# 4                            13.9%
# 5                            14.3%
# 6                            12.9%
# 7                             5.6%
# 8                             4.2%
# 9                             1.4%
# 10                            1.8%
# 11                          27,669
# 12                          41,678
# 13                             NaN
# 14                             (X)
# 15                           39.3%
# 16                             (X)
#
#    Puerto Rico!!Married-couple families!!Estimate  \
# 0                                         401,781
# 1                                            8.7%
# 2                                            7.3%
# 3                                           17.4%
# 4                                           14.7%
# 5                                           16.7%
# 6                                           16.8%
# 7                                            7.5%
# 8                                            5.8%
# 9                                            2.2%
# 10                                           3.0%
# 11                                         36,333
# 12                                         53,721
# 13                                            NaN
# 14                                            (X)
# 15                                            (X)
# 16                                            (X)
#
#    Puerto Rico!!Nonfamily households!!Estimate  \
# 0                                      427,129
# 1                                        37.8%
# 2                                        16.8%
# 3                                        18.9%
# 4                                        10.2%
# 5                                         7.2%
# 6                                         4.8%
# 7                                         2.1%
# 8                                         1.4%
# 9                                         0.3%
# 10                                        0.4%
# 11                                      13,535
# 12                                      21,531
# 13                                         NaN
# 14                                         (X)
# 15                                         (X)
# 16                                       28.0%
#
#    United States!!Households!!Estimate United States!!Families!!Estimate  \
# 0                          127,544,730                        82,464,986
# 1                                 6.0%                              3.7%
# 2                                 3.9%                              2.0%
# 3                                 7.5%                              5.0%
# 4                                 7.8%                              6.2%
# 5                                11.3%                             10.0%
# 6                                16.8%                             16.6%
# 7                                12.8%                             14.1%
# 8                                16.3%                             19.6%
# 9                                 7.9%                             10.0%
# 10                                9.8%                             12.8%
# 11                              69,717                            85,806
# 12                              97,962                           115,522
# 13                                 NaN                               NaN
# 14                               39.1%                               (X)
# 15                                 (X)                             40.9%
# 16                                 (X)                               (X)
#
#    United States!!Married-couple families!!Estimate  \
# 0                                        60,360,084
# 1                                              1.6%
# 2                                              1.0%
# 3                                              3.0%
# 4                                              4.3%
# 5                                              8.1%
# 6                                             15.6%
# 7                                             15.0%
# 8                                             22.7%
# 9                                             12.4%
# 10                                            16.3%
# 11                                          102,432
# 12                                          134,093
# 13                                              NaN
# 14                                              (X)
# 15                                              (X)
# 16                                              (X)
#
#    United States!!Nonfamily households!!Estimate
# 0                                     45,079,744
# 1                                          11.3%
# 2                                           7.6%
# 3                                          12.8%
# 4                                          11.4%
# 5                                          14.1%
# 6                                          17.1%
# 7                                           9.7%
# 8                                           9.1%
# 9                                           3.4%
# 10                                          3.5%
# 11                                        41,549
# 12                                        61,091
# 13                                           NaN
# 14                                           (X)
# 15                                           (X)
# 16                                         34.1%
#
# [17 rows x 213 columns]>

# %%
df_income.describe()
# Out:
#        Label (Grouping) Alabama!!Households!!Estimate  \
# count                17                            16
# unique               17                            15
# top               Total                           (X)
# freq                  1                             2
#
#        Alabama!!Families!!Estimate Alabama!!Married-couple families!!Estimate  \
# count                           16                                         16
# unique                          15                                         14
# top                            (X)                                        (X)
# freq                             2                                          3
#
#        Alabama!!Nonfamily households!!Estimate Alaska!!Households!!Estimate  \
# count                                       16                           16
# unique                                      15                           15
# top                                        (X)                          (X)
# freq                                         2                            2
#
#        Alaska!!Families!!Estimate Alaska!!Married-couple families!!Estimate  \
# count                          16                                        16
# unique                         15                                        14
# top                           (X)                                       (X)
# freq                            2                                         3
#
#        Alaska!!Nonfamily households!!Estimate Arizona!!Households!!Estimate  \
# count                                      16                            16
# unique                                     14                            15
# top                                     10.7%                           (X)
# freq                                        2                             2
#
#         ... Wyoming!!Married-couple families!!Estimate  \
# count   ...                                         16
# unique  ...                                         14
# top     ...                                        (X)
# freq    ...                                          3
#
#        Wyoming!!Nonfamily households!!Estimate  \
# count                                       16
# unique                                      15
# top                                        (X)
# freq                                         2
#
#        Puerto Rico!!Households!!Estimate Puerto Rico!!Families!!Estimate  \
# count                                 16                              16
# unique                                15                              15
# top                                  (X)                             (X)
# freq                                   2                               2
#
#        Puerto Rico!!Married-couple families!!Estimate  \
# count                                              16
# unique                                             14
# top                                               (X)
# freq                                                3
#
#        Puerto Rico!!Nonfamily households!!Estimate  \
# count                                           16
# unique                                          15
# top                                            (X)
# freq                                             2
#
#        United States!!Households!!Estimate United States!!Families!!Estimate  \
# count                                   16                                16
# unique                                  15                                14
# top                                    (X)                             10.0%
# freq                                     2                                 2
#
#        United States!!Married-couple families!!Estimate  \
# count                                                16
# unique                                               14
# top                                                 (X)
# freq                                                  3
#
#        United States!!Nonfamily households!!Estimate
# count                                             16
# unique                                            15
# top                                              (X)
# freq                                               2
#
# [4 rows x 213 columns]

# %%
df_income.columns
# Out:
# Index(['Label (Grouping)', 'Alabama!!Households!!Estimate',
#        'Alabama!!Families!!Estimate',
#        'Alabama!!Married-couple families!!Estimate',
#        'Alabama!!Nonfamily households!!Estimate',
#        'Alaska!!Households!!Estimate', 'Alaska!!Families!!Estimate',
#        'Alaska!!Married-couple families!!Estimate',
#        'Alaska!!Nonfamily households!!Estimate',
#        'Arizona!!Households!!Estimate',
#        ...
#        'Wyoming!!Married-couple families!!Estimate',
#        'Wyoming!!Nonfamily households!!Estimate',
#        'Puerto Rico!!Households!!Estimate', 'Puerto Rico!!Families!!Estimate',
#        'Puerto Rico!!Married-couple families!!Estimate',
#        'Puerto Rico!!Nonfamily households!!Estimate',
#        'United States!!Households!!Estimate',
#        'United States!!Families!!Estimate',
#        'United States!!Married-couple families!!Estimate',
#        'United States!!Nonfamily households!!Estimate'],
#       dtype='object', length=213)

# %% [markdown]
# # Third Dataset: Poverty Status in the Past 12 Months

# %%
df_poverty = pd.read_csv("/content/drive/MyDrive/DS4A/DS4A Team 14 - Fall 2022/DATA CURATION/Data Source Copies/US Census/3_POVERTY STATUS IN THE PAST 12 MONTHS.csv", delimiter=',')
df_poverty.head(6)
# Out:
#                                     Label (Grouping) Alabama!!Total!!Estimate  \
# 0   Population for whom poverty status is determined                4,920,613
# 1                                                AGE                      NaN
# 2                                     Under 18 years                1,103,627
# 3                                      Under 5 years                  284,569
# 4                                      5 to 17 years                  819,058
# 5              Related children of householder un...                1,099,955
#
#   Alabama!!Below poverty level!!Estimate  \
# 0                                794,326
# 1                                    NaN
# 2                                245,003
# 3                                 72,048
# 4                                172,955
# 5                                242,070
#
#   Alabama!!Percent below poverty level!!Estimate Alaska!!Total!!Estimate  \
# 0                                          16.1%                 716,769
# 1                                            NaN                     NaN
# 2                                          22.2%                 176,588
# 3                                          25.3%                  45,602
# 4                                          21.1%                 130,986
# 5                                          22.0%                 175,688
#
#   Alaska!!Below poverty level!!Estimate  \
# 0                                75,165
# 1                                   NaN
# 2                                21,833
# 3                                 5,257
# 4                                16,576
# 5                                20,990
#
#   Alaska!!Percent below poverty level!!Estimate Arizona!!Total!!Estimate  \
# 0                                         10.5%                7,126,930
# 1                                           NaN                      NaN
# 2                                         12.4%                1,586,648
# 3                                         11.5%                  393,653
# 4                                         12.7%                1,192,995
# 5                                         11.9%                1,577,969
#
#   Arizona!!Below poverty level!!Estimate  \
# 0                                908,961
# 1                                    NaN
# 2                                275,064
# 3                                 74,309
# 4                                200,755
# 5                                267,369
#
#   Arizona!!Percent below poverty level!!Estimate  ...  \
# 0                                          12.8%  ...
# 1                                            NaN  ...
# 2                                          17.3%  ...
# 3                                          18.9%  ...
# 4                                          16.8%  ...
# 5                                          16.9%  ...
#
#   Wisconsin!!Percent below poverty level!!Estimate Wyoming!!Total!!Estimate  \
# 0                                            10.8%                  565,760
# 1                                              NaN                      NaN
# 2                                            13.4%                  128,980
# 3                                            14.2%                   29,595
# 4                                            13.1%                   99,385
# 5                                            13.1%                  128,468
#
#   Wyoming!!Below poverty level!!Estimate  \
# 0                                 64,224
# 1                                    NaN
# 2                                 17,330
# 3                                  4,567
# 4                                 12,763
# 5                                 16,878
#
#   Wyoming!!Percent below poverty level!!Estimate Puerto Rico!!Total!!Estimate  \
# 0                                          11.4%                    3,235,303
# 1                                            NaN                          NaN
# 2                                          13.4%                      541,690
# 3                                          15.4%                      103,524
# 4                                          12.8%                      438,166
# 5                                          13.1%                      540,232
#
#   Puerto Rico!!Below poverty level!!Estimate  \
# 0                                  1,310,464
# 1                                        NaN
# 2                                    297,526
# 3                                     59,385
# 4                                    238,141
# 5                                    296,068
#
#   Puerto Rico!!Percent below poverty level!!Estimate  \
# 0                                              40.5%
# 1                                                NaN
# 2                                              54.9%
# 3                                              57.4%
# 4                                              54.3%
# 5                                              54.8%
#
#   United States!!Total!!Estimate United States!!Below poverty level!!Estimate  \
# 0                    324,173,084                                   41,393,176
# 1                            NaN                                          NaN
# 2                     72,297,129                                   12,243,219
# 3                     18,313,189                                    3,349,149
# 4                     53,983,940                                    8,894,070
# 5                     72,013,902                                   11,985,424
#
#   United States!!Percent below poverty level!!Estimate
# 0                                              12.8%
# 1                                                NaN
# 2                                              16.9%
# 3                                              18.3%
# 4                                              16.5%
# 5                                              16.6%
#
# [6 rows x 160 columns]

# %%
df_poverty.shape
# Out:
# (69, 160)

# %% [markdown]
# # Dataset 4 Exploration: Median Gross Rent

# %%
df_rent = pd.read_csv("/content/drive/MyDrive/DS4A/DS4A Team 14 - Fall 2022/DATA CURATION/Data Source Copies/US Census/4_MEDIAN GROSS RENT BY BEDROOM.csv", delimiter=',')
df_rent.head()
# Out:
#        Label (Grouping) Alabama!!Estimate Alaska!!Estimate Arizona!!Estimate  \
# 0  Median gross rent --               NaN              NaN               NaN
# 1                Total:               861            1,259             1,253
# 2            No bedroom               664              724               973
# 3             1 bedroom               739              900             1,047
# 4            2 bedrooms               826            1,254             1,251
#
#   Arkansas!!Estimate California!!Estimate Colorado!!Estimate  \
# 0                NaN                  NaN                NaN
# 1                820                1,750              1,491
# 2                616                1,360              1,282
# 3                645                1,525              1,300
# 4                775                1,797              1,490
#
#   Connecticut!!Estimate Delaware!!Estimate District of Columbia!!Estimate  \
# 0                   NaN                NaN                            NaN
# 1                 1,277              1,208                          1,668
# 2                   921              1,036                          1,518
# 3                 1,046              1,040                          1,666
# 4                 1,355              1,178                          1,825
#
#    ... Texas!!Estimate Utah!!Estimate Vermont!!Estimate Virginia!!Estimate  \
# 0  ...             NaN            NaN               NaN                NaN
# 1  ...           1,167          1,208             1,115              1,331
# 2  ...           1,025            946               834              1,360
# 3  ...           1,026            976               834              1,221
# 4  ...           1,155          1,167             1,271              1,245
#
#   Washington!!Estimate West Virginia!!Estimate Wisconsin!!Estimate  \
# 0                  NaN                     NaN                 NaN
# 1                1,484                     767                 921
# 2                1,276                     538                 779
# 3                1,310                     557                 756
# 4                1,479                     784                 938
#
#   Wyoming!!Estimate Puerto Rico!!Estimate United States!!Estimate
# 0               NaN                   NaN                     NaN
# 1               889                 504.0                   1,191
# 2               662                 437.0                   1,057
# 3               679                 308.0                   1,042
# 4               843                 455.0                   1,185
#
# [5 rows x 54 columns]

# %%
df_rent.shape
# Out:
# (8, 54)

# %% [markdown]
# # Cleaning Columns

# %% [markdown]
# Step 1: clean column names for each dataset

# %%
#clean column names for each dataset
df_heating_fuel_clean = df_heating_fuel
#dataset1: heating fuels
df_heating_fuel_clean.columns = df_heating_fuel_clean.columns.str.strip().str.lower().str.replace('!!estimate', '')
df_heating_fuel_clean
# Out:
#                label (grouping)    alabama   alaska    arizona   arkansas  \
# 0                        Total:  1,967,559  271,311  2,817,723  1,183,675
# 1                   Utility gas    529,760  136,638    935,440    435,082
# 2      Bottled, tank, or LP gas    109,278    7,501     79,939     74,310
# 3                   Electricity  1,299,491   37,403  1,687,012    631,405
# 4      Fuel oil, kerosene, etc.      2,289   72,709      2,061      1,473
# 5                  Coal or coke         60      582        583          0
# 6                          Wood     13,644   11,092     45,318     30,391
# 7                  Solar energy        366      132     30,298        575
# 8                    Other fuel      1,411    2,487      7,915      4,430
# 9                  No fuel used     11,260    2,767     29,157      6,009
#
#    california   colorado connecticut delaware district of columbia  ...  \
# 0  13,429,063  2,313,042   1,428,313  395,656              319,565  ...
# 1   8,169,527  1,527,676     506,772  168,200              160,024  ...
# 2     464,435    113,314      80,721   36,954                3,540  ...
# 3   3,990,075    603,564     258,306  148,031              142,056  ...
# 4      30,731      2,167     532,053   34,587                4,391  ...
# 5       1,877        640         843      353                    0  ...
# 6     170,065     31,404      22,992    2,224                    0  ...
# 7     144,690     12,121       2,966      688                1,087  ...
# 8      43,531     12,059      14,306    1,996                2,396  ...
# 9     414,132     10,097       9,354    2,623                6,071  ...
#
#         texas       utah  vermont   virginia washington west virginia  \
# 0  10,796,247  1,101,499  270,163  3,331,461  3,022,255       722,201
# 1   3,652,862    852,377   50,677  1,075,840  1,012,119       298,606
# 2     321,711     27,747   51,992    145,015     95,724        36,595
# 3   6,679,670    198,288   22,510  1,905,058  1,741,348       326,799
# 4      10,027      2,138  105,005    116,452     44,429        14,852
# 5       2,502        996      226      1,297        555         2,270
# 6      28,036      8,173   33,125     53,547     87,688        37,047
# 7      21,399      3,738    1,349      3,312      4,167            52
# 8      19,922      4,325    4,533      9,742     15,521         3,718
# 9      60,118      3,717      746     21,198     20,704         2,262
#
#    wisconsin  wyoming puerto rico united states
# 0  2,449,970  242,763   1,165,982   127,544,730
# 1  1,582,718  144,576       1,015    59,246,257
# 2    296,947   26,413       7,847     6,326,791
# 3    429,522   57,846     106,536    52,279,174
# 4     36,529      161         194     5,218,757
# 5        945      508         145        95,160
# 6     67,980    9,586         106     1,792,240
# 7      1,613      517       6,454       362,346
# 8     19,067    2,204         291       640,525
# 9     14,649      952   1,043,394     1,583,480
#
# [10 rows x 54 columns]

# %%
#Dataset 2:

# %%
#first create a copy of the dataframe incase we need to resue the full dataframe
df_income_clean=df_income

#craete a list of the columns we wnat to drop
omit_names = ['.*Families*.',
              '.*Married-couple*.',
              '.*Nonfamily households*.']

#iterate thru the list and remove the columns
for item in omit_names:
  mask = df_income_clean.columns.str.contains(item)
  df_income_clean = df_income_clean.loc[:,~mask] #use the inverse of the mask to keep the columns that are False

#clean column names
df_income_clean.columns = df_income_clean.columns.str.strip().str.lower().str.replace('!!households!!estimate', '')
df_income_clean.head(5)
# Out:
#          label (grouping)    alabama   alaska    arizona   arkansas  \
# 0                   Total  1,967,559  271,311  2,817,723  1,183,675
# 1       Less than $10,000       7.7%     5.4%       5.6%       7.6%
# 2      $10,000 to $14,999       5.6%     3.0%       3.2%       5.4%
# 3      $15,000 to $24,999      10.4%     6.3%       7.1%      10.4%
# 4      $25,000 to $34,999       9.4%     6.2%       7.8%      10.0%
#
#    california   colorado connecticut delaware district of columbia  ...  \
# 0  13,429,063  2,313,042   1,428,313  395,656              319,565  ...
# 1        5.3%       4.8%        5.2%     5.2%                 9.6%  ...
# 2        3.5%       2.7%        3.3%     3.1%                 2.8%  ...
# 3        6.0%       5.4%        6.7%     7.2%                 5.5%  ...
# 4        6.2%       6.3%        6.5%     7.0%                 5.3%  ...
#
#         texas       utah  vermont   virginia washington west virginia  \
# 0  10,796,247  1,101,499  270,163  3,331,461  3,022,255       722,201
# 1        6.1%       4.3%     4.1%       5.0%       4.8%          8.4%
# 2        3.7%       2.6%     4.3%       3.1%       2.8%          5.9%
# 3        7.8%       4.7%     7.5%       6.4%       5.4%         10.9%
# 4        8.3%       6.7%     7.5%       6.8%       6.0%          9.8%
#
#    wisconsin  wyoming puerto rico united states
# 0  2,449,970  242,763   1,165,982   127,544,730
# 1       4.8%     6.0%       24.6%          6.0%
# 2       3.9%     3.7%       11.3%          3.9%
# 3       7.2%     8.1%       18.4%          7.5%
# 4       8.3%     8.9%       12.8%          7.8%
#
# [5 rows x 54 columns]

# %% [markdown]
# Datset #3:

# %%
df_poverty.head()
# Out:
#                                    Label (Grouping) Alabama!!Total!!Estimate  \
# 0  Population for whom poverty status is determined                4,920,613
# 1                                               AGE                      NaN
# 2                                    Under 18 years                1,103,627
# 3                                     Under 5 years                  284,569
# 4                                     5 to 17 years                  819,058
#
#   Alabama!!Below poverty level!!Estimate  \
# 0                                794,326
# 1                                    NaN
# 2                                245,003
# 3                                 72,048
# 4                                172,955
#
#   Alabama!!Percent below poverty level!!Estimate Alaska!!Total!!Estimate  \
# 0                                          16.1%                 716,769
# 1                                            NaN                     NaN
# 2                                          22.2%                 176,588
# 3                                          25.3%                  45,602
# 4                                          21.1%                 130,986
#
#   Alaska!!Below poverty level!!Estimate  \
# 0                                75,165
# 1                                   NaN
# 2                                21,833
# 3                                 5,257
# 4                                16,576
#
#   Alaska!!Percent below poverty level!!Estimate Arizona!!Total!!Estimate  \
# 0                                         10.5%                7,126,930
# 1                                           NaN                      NaN
# 2                                         12.4%                1,586,648
# 3                                         11.5%                  393,653
# 4                                         12.7%                1,192,995
#
#   Arizona!!Below poverty level!!Estimate  \
# 0                                908,961
# 1                                    NaN
# 2                                275,064
# 3                                 74,309
# 4                                200,755
#
#   Arizona!!Percent below poverty level!!Estimate  ...  \
# 0                                          12.8%  ...
# 1                                            NaN  ...
# 2                                          17.3%  ...
# 3                                          18.9%  ...
# 4                                          16.8%  ...
#
#   Wisconsin!!Percent below poverty level!!Estimate Wyoming!!Total!!Estimate  \
# 0                                            10.8%                  565,760
# 1                                              NaN                      NaN
# 2                                            13.4%                  128,980
# 3                                            14.2%                   29,595
# 4                                            13.1%                   99,385
#
#   Wyoming!!Below poverty level!!Estimate  \
# 0                                 64,224
# 1                                    NaN
# 2                                 17,330
# 3                                  4,567
# 4                                 12,763
#
#   Wyoming!!Percent below poverty level!!Estimate Puerto Rico!!Total!!Estimate  \
# 0                                          11.4%                    3,235,303
# 1                                            NaN                          NaN
# 2                                          13.4%                      541,690
# 3                                          15.4%                      103,524
# 4                                          12.8%                      438,166
#
#   Puerto Rico!!Below poverty level!!Estimate  \
# 0                                  1,310,464
# 1                                        NaN
# 2                                    297,526
# 3                                     59,385
# 4                                    238,141
#
#   Puerto Rico!!Percent below poverty level!!Estimate  \
# 0                                              40.5%
# 1                                                NaN
# 2                                              54.9%
# 3                                              57.4%
# 4                                              54.3%
#
#   United States!!Total!!Estimate United States!!Below poverty level!!Estimate  \
# 0                    324,173,084                                   41,393,176
# 1                            NaN                                          NaN
# 2                     72,297,129                                   12,243,219
# 3                     18,313,189                                    3,349,149
# 4                     53,983,940                                    8,894,070
#
#   United States!!Percent below poverty level!!Estimate
# 0                                              12.8%
# 1                                                NaN
# 2                                              16.9%
# 3                                              18.3%
# 4                                              16.5%
#
# [5 rows x 160 columns]

# %%
#first create a copy of the dataframe incase we need to resue the full dataframe
df_poverty_clean=df_poverty

#craete a list of the columns we wnat to drop
omit_names = ['.*!!Total!!*.',
              '.*!!Below poverty level!!Estimate*.']

#iterate thru the list and remove the columns
for item in omit_names:
  mask = df_poverty_clean.columns.str.contains(item)
  df_poverty_clean = df_poverty_clean.loc[:,~mask] #use the inverse of the mask to keep the columns that are False

# clean column names
df_poverty_clean.columns = df_poverty_clean.columns.str.strip().str.lower().str.replace('!!percent below poverty level!!estimate', '')
df_poverty_clean.head(5)
# Out:
#                                    label (grouping) alabama alaska arizona  \
# 0  Population for whom poverty status is determined   16.1%  10.5%   12.8%
# 1                                               AGE     NaN    NaN     NaN
# 2                                    Under 18 years   22.2%  12.4%   17.3%
# 3                                     Under 5 years   25.3%  11.5%   18.9%
# 4                                     5 to 17 years   21.1%  12.7%   16.8%
#
#   arkansas california colorado connecticut delaware district of columbia  ...  \
# 0    16.3%      12.3%     9.7%       10.1%    11.6%                16.5%  ...
# 1      NaN        NaN      NaN         NaN      NaN                  NaN  ...
# 2    22.4%      15.8%    11.8%       12.7%    16.8%                23.9%  ...
# 3    26.5%      15.6%    13.0%       13.5%    21.4%                20.1%  ...
# 4    20.9%      15.9%    11.4%       12.5%    15.3%                25.6%  ...
#
#    texas  utah vermont virginia washington west virginia wisconsin wyoming  \
# 0  14.2%  8.6%   10.3%    10.2%       9.9%         16.8%     10.8%   11.4%
# 1    NaN   NaN     NaN      NaN        NaN           NaN       NaN     NaN
# 2  19.6%  8.1%   10.4%    13.1%      12.0%         20.7%     13.4%   13.4%
# 3  21.2%  9.7%   11.4%    14.3%      12.6%         26.1%     14.2%   15.4%
# 4  19.0%  7.6%   10.1%    12.7%      11.8%         19.0%     13.1%   12.8%
#
#   puerto rico united states
# 0       40.5%         12.8%
# 1         NaN           NaN
# 2       54.9%         16.9%
# 3       57.4%         18.3%
# 4       54.3%         16.5%
#
# [5 rows x 54 columns]

# %% [markdown]
# Dataset 4:

# %%
df_rent_clean = df_rent
# clean column names
df_rent_clean.columns = df_rent_clean.columns.str.strip().str.lower().str.replace('!!estimate', '')
df_rent_clean.head(5)
# Out:
#        label (grouping) alabama alaska arizona arkansas california colorado  \
# 0  Median gross rent --     NaN    NaN     NaN      NaN        NaN      NaN
# 1                Total:     861  1,259   1,253      820      1,750    1,491
# 2            No bedroom     664    724     973      616      1,360    1,282
# 3             1 bedroom     739    900   1,047      645      1,525    1,300
# 4            2 bedrooms     826  1,254   1,251      775      1,797    1,490
#
#   connecticut delaware district of columbia  ...  texas   utah vermont  \
# 0         NaN      NaN                  NaN  ...    NaN    NaN     NaN
# 1       1,277    1,208                1,668  ...  1,167  1,208   1,115
# 2         921    1,036                1,518  ...  1,025    946     834
# 3       1,046    1,040                1,666  ...  1,026    976     834
# 4       1,355    1,178                1,825  ...  1,155  1,167   1,271
#
#   virginia washington west virginia wisconsin wyoming puerto rico  \
# 0      NaN        NaN           NaN       NaN     NaN         NaN
# 1    1,331      1,484           767       921     889       504.0
# 2    1,360      1,276           538       779     662       437.0
# 3    1,221      1,310           557       756     679       308.0
# 4    1,245      1,479           784       938     843       455.0
#
#   united states
# 0           NaN
# 1         1,191
# 2         1,057
# 3         1,042
# 4         1,185
#
# [5 rows x 54 columns]

# %% [markdown]
# # Transpose Dataset

# %%
#transposing all datasets
df_heating_fuel_transpose = df_heating_fuel_clean.transpose()
df_income_transpose = df_income_clean.transpose()
df_poverty_transpose = df_poverty_clean.transpose()
df_rent_transpose = df_rent_clean.transpose()

# %%
df_poverty_transpose.head()
#notice header names are not the correct ones, need to reset them
# Out:
#                                                                 0        1   \
# label (grouping)  Population for whom poverty status is determined      AGE
# alabama                                                      16.1%      NaN
# alaska                                                       10.5%      NaN
# arizona                                                      12.8%      NaN
# arkansas                                                     16.3%      NaN
#
#                                       2                          3   \
# label (grouping)          Under 18 years              Under 5 years
# alabama                            22.2%                      25.3%
# alaska                             12.4%                      11.5%
# arizona                            17.3%                      18.9%
# arkansas                           22.4%                      26.5%
#
#                                          4   \
# label (grouping)              5 to 17 years
# alabama                               21.1%
# alaska                                12.7%
# arizona                               16.8%
# arkansas                              20.9%
#
#                                                                  5   \
# label (grouping)              Related children of householder un...
# alabama                                                       22.0%
# alaska                                                        11.9%
# arizona                                                       16.9%
# arkansas                                                      22.1%
#
#                                       6                           7   \
# label (grouping)          18 to 64 years              18 to 34 years
# alabama                            15.3%                       18.8%
# alaska                             10.2%                       11.8%
# arizona                            12.0%                       14.6%
# arkansas                           15.2%                       18.0%
#
#                                           8                          9   ...  \
# label (grouping)              35 to 64 years          60 years and over  ...
# alabama                                13.3%                      12.2%  ...
# alaska                                  9.1%                       8.7%  ...
# arizona                                10.4%                      10.0%  ...
# arkansas                               13.7%                      12.7%  ...
#
#                                   59                  60                  61  \
# label (grouping)      35 to 44 years      45 to 54 years      55 to 64 years
# alabama                        29.7%               28.3%               33.9%
# alaska                         17.0%               18.8%               20.0%
# arizona                        18.9%               21.9%               26.0%
# arkansas                       29.5%               26.4%               35.6%
#
#                                   62                     63  \
# label (grouping)      65 to 74 years      75 years and over
# alabama                        22.6%                  22.8%
# alaska                         19.5%                  12.7%
# arizona                        19.2%                  19.3%
# arkansas                       28.1%                  23.0%
#
#                                                                  64  \
# label (grouping)      Mean income deficit for unrelated individu...
# alabama                                                         (X)
# alaska                                                          (X)
# arizona                                                         (X)
# arkansas                                                        (X)
#
#                                                                  65  \
# label (grouping)      Worked full-time, year-round in the past 1...
# alabama                                                        5.0%
# alaska                                                         3.9%
# arizona                                                        2.9%
# arkansas                                                       3.3%
#
#                                                                  66  \
# label (grouping)      Worked less than full-time, year-round in ...
# alabama                                                       40.6%
# alaska                                                        24.5%
# arizona                                                       31.5%
# arkansas                                                      42.1%
#
#                                 67  \
# label (grouping)      Did not work
# alabama                      46.8%
# alaska                       42.3%
# arizona                      41.8%
# arkansas                     48.7%
#
#                                                                  68
# label (grouping)      Population in housing units for whom pover...
# alabama                                                       16.0%
# alaska                                                        10.3%
# arizona                                                       12.6%
# arkansas                                                      16.2%
#
# [5 rows x 69 columns]

# %%
# correct first column name for each dataset
#Dataset 1 
fuel_data = df_heating_fuel_transpose.rename(columns=df_heating_fuel_transpose.iloc[0])
fuel_data = fuel_data.drop(index="label (grouping)", axis=0)

#Dataset 2
income_data = df_income_transpose.rename(columns=df_income_transpose.iloc[0])
income_data = income_data.drop(index="label (grouping)", axis=0)

#Dataset 3
poverty_data = df_poverty_transpose.rename(columns=df_poverty_transpose.iloc[0])
poverty_data = poverty_data.drop(index="label (grouping)", axis=0)

#Dataset 4
rent_data = df_rent_transpose.rename(columns=df_rent_transpose.iloc[0]) 
rent_data = rent_data.drop(index="label (grouping)", axis=0)

# %% [markdown]
# # Clean Transposed Data

# %%
#Clean Transposed Data for heating fuel
fuel_data =fuel_data.drop(columns=['Total:'])
fuel_data.columns= fuel_data.columns.str.strip().str.lower()
fuel_data =fuel_data.reset_index()
fuel_data = fuel_data.rename(columns={'index': 'state'})
fuel_data.head(1)
# Out:
#      state utility gas bottled, tank, or lp gas electricity  \
# 0  alabama     529,760                  109,278   1,299,491
#
#   fuel oil, kerosene, etc. coal or coke    wood solar energy other fuel  \
# 0                    2,289           60  13,644          366      1,411
#
#   no fuel used
# 0       11,260

# %%
#clean income data
income_data = income_data[['Median income (dollars)','Mean income (dollars)']]
income_data.columns= income_data.columns.str.strip().str.lower()
income_data =income_data.reset_index()
income_data = income_data.rename(columns={'index': 'state'})
income_data.head(1)
# Out:
#      state median income (dollars) mean income (dollars)
# 0  alabama                  53,913                75,923

# %%
#Clean Poverty Data
#poverty_data.columns
poverty_data = poverty_data[['Population for whom poverty status is determined']]
poverty_data.columns= poverty_data.columns.str.strip().str.lower()
poverty_data =poverty_data.reset_index()
poverty_data = poverty_data.rename(columns={'index': 'state'})
poverty_data.head(1)
# Out:
#      state population for whom poverty status is determined
# 0  alabama                                            16.1%

# %%
#Clean Rent Data
#rent_data.columns
rent_data.columns= rent_data.columns.str.strip().str.lower()
rent_data =rent_data.reset_index()
rent_data = rent_data.rename(columns={'index': 'state','median gross rent --': 'delete', 'total:': 'median gross rent'})
rent_data =rent_data.drop(columns=['delete','no bedroom', '1 bedroom', '2 bedrooms','3 bedrooms', '4 bedrooms', '5 or more bedrooms'])
rent_data.head(1)
# Out:
#      state median gross rent
# 0  alabama               861

# %% [markdown]
# #  Merge with only rows we want

# %%
# compile the list of dataframes we want to merge
data_frames = [income_data, poverty_data, rent_data, fuel_data]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['state'],how='outer'), data_frames)

df_merged.head(3)
# Out:
#      state median income (dollars) mean income (dollars)  \
# 0  alabama                  53,913                75,923
# 1   alaska                  77,845               100,519
# 2  arizona                  69,056                93,177
#
#   population for whom poverty status is determined median gross rent
# 0                                            16.1%               861
# 1                                            10.5%             1,259
# 2                                            12.8%             1,253

# %%
#clean Merged data
census = df_merged
census = census.rename(columns={'median income (dollars)': 'median_income',
                                'mean income (dollars)': 'mean_income', 
                                'population for whom poverty status is determined': 'percent_poverty',
                                'median gross rent': 'median_gross_rent'
                                })

census.columns
# Out:
# Index(['state', 'median_income', 'mean_income', 'percent_poverty',
#        'median_gross_rent', 'utility gas', 'bottled, tank, or lp gas',
#        'electricity', 'fuel oil, kerosene, etc.', 'coal or coke', 'wood',
#        'solar energy', 'other fuel', 'no fuel used'],
#       dtype='object')

# %%
#Clean Data Types
census['median_income'] = census['median_income'].str.replace(',', '').astype(int)
census['mean_income'] = census['mean_income'].str.replace(',', '').astype(int)
census['percent_poverty'] = census['percent_poverty'].str.replace('%', '').astype(float)
#census['median_gross_rent'] = census['median_gross_rent'].str.replace(',', '').astype(int)
census['utility gas'] = census['utility gas'].str.replace(',', '').astype(int)
census['bottled, tank, or lp gas'] = census['bottled, tank, or lp gas'].str.replace(',', '').astype(int)
census['electricity'] = census['electricity'].str.replace(',', '').astype(int)
census['fuel oil, kerosene, etc.'] = census['fuel oil, kerosene, etc.'].str.replace(',', '').astype(int)
census['coal or coke'] = census['coal or coke'].str.replace(',', '').astype(int)
census['wood'] = census['wood'].str.replace(',', '').astype(int)
census['solar energy'] = census['solar energy'].str.replace(',', '').astype(int)
census['other fuel'] = census['other fuel'].str.replace(',', '').astype(int)
census['no fuel used'] = census['no fuel used'].str.replace(',', '').astype(int)

census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 0 to 52
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     53 non-null     object
#  1   median_income             53 non-null     int64
#  2   mean_income               53 non-null     int64
#  3   percent_poverty           53 non-null     float64
#  4   median_gross_rent         53 non-null     object
#  5   utility gas               53 non-null     int64
#  6   bottled, tank, or lp gas  53 non-null     int64
#  7   electricity               53 non-null     int64
#  8   fuel oil, kerosene, etc.  53 non-null     int64
#  9   coal or coke              53 non-null     int64
#  10  wood                      53 non-null     int64
#  11  solar energy              53 non-null     int64
#  12  other fuel                53 non-null     int64
#  13  no fuel used              53 non-null     int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 6.2+ KB
